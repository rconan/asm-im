# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("dark_background")

# %%
data = pd.read_parquet("data.parquet")
data.columns
# Out:
# Index(['M1RigidBodyMotions', 'MCM2Lcl6D', 'M1BendingModes',
#        'OSSM1EdgeSensors'],
#       dtype='object')

# %%
data05 = pd.read_parquet("data-05pct.parquet")
data05.columns
# Out:
# Index(['MountEncoders', 'OSSM1Lcl', 'OSSTrussIF6D', 'MCM2Lcl6D'], dtype='object')

# %%
t = np.arange(len(data))/1e3
fig,axs = plt.subplots(nrows=3,sharex=True,figsize=(15,15))
ax = axs[0]
ax.plot(t,np.vstack(data2["MountEncoders"])[:,:4].mean(1));
ax.grid()
ax = axs[1]
ax.plot(t, np.vstack(data2["MountEncoders"])[:, 4:10].mean(1))
ax.grid()
ax = axs[2]
ax.plot(t, np.vstack(data2["MountEncoders"])[:, 10:].mean(1))
ax.grid()
ax = axs[0]
ax.plot(t, np.vstack(data05["MountEncoders"])[:, :4].mean(1))
ax.grid()
ax = axs[1]
ax.plot(t, np.vstack(data05["MountEncoders"])[:, 4:10].mean(1))
ax.grid()
ax = axs[2]
ax.plot(t, np.vstack(data05["MountEncoders"])[:, 10:].mean(1))
ax.grid()
ax.legend(['2pct','0.5pct'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MountEncoders'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-76fb41874b74> in <module>()
# ...

# %%
len(data)
# Out:
# 10000

# %%
t = np.arange(len(data))/2e3
plt.plot(t,np.vstack(data["M1RigidBodyMotions"]));

# %%
plt.plot(np.vstack(data["OSSM1Lcl"]));

# %%
plt.plot(np.vstack(data["MCM2Lcl6D"]));

# %%
data = pd.read_parquet("data.parquet")
t = np.arange(len(data))/2e3
plt.plot(t,np.vstack(data["M1RigidBodyMotions"])[:,0]);
for k in range(5):
    data = pd.read_parquet(f"asms-im_windloading-part{k}.parquet")
    t = np.arange(len(data))/2e3 + k
    plt.plot(t,np.vstack(data["M1RigidBodyMotions"])[:,0]);

# %%
root = "/fsx/CASES/zen00az000_CD12/"

# %%
for k in range(3):
    data = pd.read_parquet(f"{root}/asms-im_windloading-part{k}.parquet")
    t = np.arange(len(data))/2e3 + k*40
    plt.plot(t,np.vstack(data["M1RigidBodyMotions"])[:,0]);
data = pd.read_parquet("data.parquet")
t = np.arange(len(data))/2e3
plt.plot(t, np.vstack(data["M1RigidBodyMotions"])[:, 0],'k')

# %%
#data = pd.read_parquet("/fsx/CASES/zen30az000_OS7/windloading.parquet")
#t = np.arange(len(data))/1e3
#plt.plot(t,np.vstack(data["M1RigidBodyMotions"])[:,0]);
#plt.xlim([25,30])
for k in range(3):
    data = pd.read_parquet(f"{root}/asms-im_windloading-part{k}.parquet")
    data.rename(columns={'MCM2Lcl6D': 'M2RigidBodyMotions'}, inplace=True)
    t = np.arange(len(data))/2e3 + k*40
    plt.plot(t,np.vstack(data["M2RigidBodyMotions"]));

# %%
plt.plot(np.vstack(data["MCM2CP6F"])[:,:3]);
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MCM2CP6F'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-4952705614b9> in <module>()
# ...

# %%
plt.plot(np.vstack(data["MCM2CP6F"])[:,3:6]);

# %%
plt.plot(np.vstack(data["MCM2CP6F"])[:,6:]);

# %%
plt.plot(np.vstack(data["MCM2RB6F"]));

# %%
plt.plot(np.vstack(data["MCM2Lcl6F"])[:,:6]);

# %%
plt.plot(np.vstack(data["MCM2Lcl6F"])[:,6:]);

# %%
plt.plot(np.vstack(data["MCM2RB6D"]));

# %%
plt.plot(np.vstack(data["MCM2Lcl6D"]));

# %%
y_rbfs = np.vstack(data["MCM2RB6D"])-np.vstack(data["MCM2Lcl6D"])
y_rbfs.shape
# Out:
# (24000, 42)

# %%
plt.plot(y_rbfs[:,:3]);

# %%
plt.plot(y_rbfs[:,3:6]);

# %%
plt.plot(y_rbfs[:, 6:]);

# %%
np.vstack(data["M1BendingModes"])[:10,162]
# Out:
# array([-2.42297633e-06, -2.41833576e-06, -2.41356055e-06, -2.40866994e-06,
#        -2.40367460e-06, -2.39858233e-06, -2.39340576e-06, -2.38816566e-06,
#        -2.38289341e-06, -2.37760740e-06])

# %%
np.vstack(data["M1BendingModes"]).reshape(-1,7,162)[:10,1,0]
# Out:
# array([-2.42297633e-06, -2.41833576e-06, -2.41356055e-06, -2.40866994e-06,
#        -2.40367460e-06, -2.39858233e-06, -2.39340576e-06, -2.38816566e-06,
#        -2.38289341e-06, -2.37760740e-06])

# %%
plt.plot(np.vstack(data["M1BendingModes"]).reshape(-1,7,162)[-100:,0,4])
